# %% [markdown]
# # Filtering dataframe

# %% [markdown]
# # Single condition
# ## 1. i want those matches which play  Islamabad United

# %%
import numpy as np
import pandas as pd

data=pd.read_csv('battingavg.csv')
mask=data['Team Name']=='Islamabad United'
data[mask]
# Out:
#     Unnamed: 0               Player       Span  Mat Inns NO Runs   HS    Ave  \
# 0            0          Abrar Ahmed  2023-2023    3    2  0    0    0   0.00
# 1            1  Ahmed Safi Abdullah  2020-2020    3    2  2    9   8*      -
# 2            2           Akif Javed  2020-2021   11    3  3    0   0*      -
# 3            3             Ali Khan  2021-2021    3    -  -    -    -      -
# 4            4            Amad Butt  2017-2020   16    9  2   60   17   8.57
# ..         ...                  ...        ...  ...  ... ..  ...  ...    ...
# 74          74          Zafar Gohar  2018-2022   11    6  3   39  13*  13.00
# 75          75        Zahid Mahmood  2022-2022    2    1  1    3   3*      -
# 76          76           Zahir Khan  2022-2022    2    1  1    0   0*      -
# 77          77       Zeeshan Zameer  2022-2023    3    1  0    0    0   0.00
# 78          78          Zohaib Khan  2017-2017    1    -  -    -    -      -
#
# ...

# %% [markdown]
# # More then one condition
# #
# ## play in Islamabad United and year is 2023

# %%
import numpy as np
import pandas as pd

data=pd.read_csv('battingavg.csv')
mask1=data['Team Name']=='Islamabad United'
mask2=data['Span']>'2023'
data[mask1 & mask2]
# Out:
#     Unnamed: 0             Player       Span  Mat Inns NO Runs   HS    Ave  \
# 0            0        Abrar Ahmed  2023-2023    3    2  0    0    0   0.00
# 14          14          TK Curran  2023-2023    5    3  1   21  10*  10.50
# 23          23   Fazalhaq Farooqi  2023-2023    6    2  1    0   0*   0.00
# 29          29       Hassan Nawaz  2023-2023    3    3  0   28   21   9.33
# 66          66     Sohaib Maqsood  2023-2023    2    2  0   75   60  37.50
# 70          70  HE van der Dussen  2023-2023    6    6  0  148   49  24.66
#
#      BF      SR 100 50  0  4s 6s         Team Name
# 0     2    0.00   0  0  2   0  0  Islamabad United
# 14   11  190.90   0  0  0   1  2  Islamabad United
# 23    2    0.00   0  0  1   0  0  Islamabad United
# 29   28  100.00   0  0  1   3  1  Islamabad United
# 66   54  138.88   0  1  0   9  3  Islamabad United
# 70  116  127.58   0  0  0  16  2  Islamabad United

# %%
import numpy as np
import pandas as pd

data=pd.read_csv('battingavg.csv')
mask1=data['Team Name']=='Islamabad United'
mask2=data['Span']>'2023'
data[mask1 & mask2]
data[mask1 & mask2].shape
# Out:
# (6, 17)
