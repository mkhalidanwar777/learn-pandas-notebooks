# %% [markdown]
# # Plot Function

# %% [markdown]
# ### with the help of this we make Graph
# #
# # 1. kind='bar'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data=pd.read_csv('battingAvg.csv')

data['Team Name'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Team Name'>

# %% [markdown]
# ## kind='barh'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data=pd.read_csv('battingAvg.csv')

data['Team Name'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='Team Name'>

# %% [markdown]
# ## pi chart

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data=pd.read_csv('battingAvg.csv')
data['Team Name'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## kind='hist'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data=pd.read_csv('battingAvg.csv')

data['Team Name'].value_counts().plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data=pd.read_csv('battingAvg.csv')

data['Mat'].value_counts().plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>
