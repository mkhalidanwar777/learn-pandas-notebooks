# %% [markdown]
# # Groupby()  Function
# #
# # data.groupby('column name')

# %%
import numpy as np
import pandas as pd

company=pd.read_csv('deliveries.csv')
company.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %% [markdown]
# # now create a gruop
# ## gruop=deliveries.gruopby('batsman')

# %%
import numpy as np
import pandas as pd

batsman_name=pd.read_csv('deliveries.csv')
group=batsman_name.groupby('batsman')

# %% [markdown]
# # now check len() of both

# %%
import numpy as np
import pandas as pd

batsman_name=pd.read_csv('deliveries.csv')
group=batsman_name.groupby('batsman')

len(batsman_name)
# Out:
# 150460

# %%
import numpy as np
import pandas as pd

batsman_name=pd.read_csv('deliveries.csv')
group=batsman_name.groupby('batsman')

len(group)
# Out:
# 461

# %% [markdown]
# # group.size()

# %%
import numpy as np
import pandas as pd

batsman_name=pd.read_csv('deliveries.csv')
group=batsman_name.groupby('batsman')

group.size().head(10)
# Out:
# batsman
# A Ashish Reddy    196
# A Chandila          7
# A Chopra           75
# A Choudhary        20
# A Flintoff         57
# A Kumble           49
# A Mishra          382
# A Mithun           26
# A Mukund           23
# A Nehra            63
# dtype: int64

# %%
import numpy as np
import pandas as pd

batsman_name=pd.read_csv('deliveries.csv')
group=batsman_name.groupby('batsman')

group.size().sort_values(ascending=False).head(10)
# Out:
# batsman
# V Kohli       3494
# G Gambhir     3433
# SK Raina      3369
# RG Sharma     3274
# S Dhawan      3005
# RV Uthappa    2960
# DA Warner     2902
# MS Dhoni      2680
# AM Rahane     2602
# CH Gayle      2532
# dtype: int64

# %% [markdown]
# # rank top
# ## group.first()

# %%
import numpy as np
import pandas as pd

batsman_name=pd.read_csv('deliveries.csv')
group=batsman_name.groupby('batsman')

group.first(5)
# Out:
#                 match_id  inning  over  ball  is_super_over  wide_runs  \
# batsman
# A Ashish Reddy       346       1    14     1              0          0
# A Chandila           373       1    20     6              0          0
# A Chopra              88       1     1     1              0          0
# A Choudhary            1       2    20     3              0          0
# A Flintoff           118       2     4     1              0          0
# ...                  ...     ...   ...   ...            ...        ...
# YV Takawale           82       1     1     1              0          0
# Yashpal Singh        126       2    15     2              0          0
# Younis Khan           97       2     2     4              0          0
# Yuvraj Singh           1       1    11     5              0          0
# Z Khan                 5       2    20     5              0          0
#
#                 bye_runs  legbye_runs  noball_runs  penalty_runs  \
# batsman
# ...

# %% [markdown]
# # last 5 rank
# ## group.last().head()

# %%
import numpy as np
import pandas as pd

batsman_name=pd.read_csv('deliveries.csv')
group=batsman_name.groupby('batsman')

group.last(5)
# Out:
#                 match_id  inning  over  ball  is_super_over  wide_runs  \
# batsman
# A Ashish Reddy       603       1    20     6              0          0
# A Chandila           407       1    20     2              0          0
# A Chopra             121       1    11     4              0          0
# A Choudhary           42       2    19     6              0          0
# A Flintoff           125       2    16     6              0          0
# ...                  ...     ...   ...   ...            ...        ...
# YV Takawale          510       1     5     5              0          0
# Yashpal Singh        168       2     5     7              0          0
# Younis Khan           97       2     5     5              0          0
# Yuvraj Singh         636       1    17     2              0          0
# Z Khan               623       2    20     1              0          0
#
#                 bye_runs  legbye_runs  noball_runs  penalty_runs  \
# batsman
# ...

# %% [markdown]
# # group.groups
# ## it give you a dictionary in which have group  name and index

# %%
import numpy as np
import pandas as pd

batsman_name=pd.read_csv('deliveries.csv')
group=batsman_name.groupby('batsman')

group.groups
# Out:
# {'A Ashish Reddy': [81613, 81614, 81615, 81616, 81618, 81622, 81623, 81624, 81625, 81626, 83206, 83211, 83212, 84897, 84899, 84900, 84902, 84903, 84904, 84906, 84907, 88280, 88281, 88282, 88283, 88883, 88884, 88885, 88887, 88889, 90831, 90838, 90840, 90841, 91881, 91883, 91884, 91885, 91887, 91889, 91890, 91892, 91894, 91895, 91897, 91898, 93322, 93324, 93325, 93326, 93327, 93329, 93330, 93331, 93332, 94073, 94076, 94077, 94079, 94080, 95178, 95182, 95184, 95185, 95187, 95188, 95190, 95191, 95192, 95194, 95197, 95198, 95200, 95201, 95204, 96018, 96022, 96024, 96026, 96027, 96028, 96032, 98057, 98058, 98059, 98062, 98063, 98064, 98065, 98068, 98071, 98072, 98077, 98078, 98079, 98080, 98081, 98082, 98534, 98535, ...], 'A Chandila': [88164, 96372, 96374, 96375, 96385, 96386, 96387], 'A Chopra': [20477, 20478, 20482, 20484, 20490, 21373, 21374, 21375, 21376, 21380, 21381, 21390, 21401, 21402, 21403, 21409, 21413, 21414, 21415, 21416, 21418, 21419, 21420, 21421, 21422, 21424, 21425, 21426
# ...

# %% [markdown]
# ## now data fache with the help is index which is giving in this dictionary

# %%
import numpy as np
import pandas as pd

batsman_name=pd.read_csv('deliveries.csv')
group=batsman_name.groupby('batsman')

batsman_name.iloc[81613, :]
# Out:
# match_id                        346
# inning                            1
# batting_team        Deccan Chargers
# bowling_team         Mumbai Indians
# over                             14
# ball                              1
# batsman              A Ashish Reddy
# non_striker               JP Duminy
# bowler                  RJ Peterson
# is_super_over                     0
# wide_runs                         0
# bye_runs                          0
# legbye_runs                       0
# noball_runs                       0
# penalty_runs                      0
# batsman_runs                      0
# extra_runs                        0
# total_runs                        0
# player_dismissed                NaN
# dismissal_kind                  NaN
# fielder                         NaN
# Name: 81613, dtype: object

# %% [markdown]
# # group.get_group('A Ashish Reddy')

# %%
import numpy as np
import pandas as pd

batsman_name=pd.read_csv('deliveries.csv')
group=batsman_name.groupby('batsman')

group.get_group('A Ashish Reddy')
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 81613        346       1      Deccan Chargers               Mumbai Indians
# 81614        346       1      Deccan Chargers               Mumbai Indians
# 81615        346       1      Deccan Chargers               Mumbai Indians
# 81616        346       1      Deccan Chargers               Mumbai Indians
# 81618        346       1      Deccan Chargers               Mumbai Indians
# ...          ...     ...                  ...                          ...
# 138073       584       1  Sunrisers Hyderabad        Kolkata Knight Riders
# 138074       584       1  Sunrisers Hyderabad        Kolkata Knight Riders
# 142600       603       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 142601       603       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 142603       603       1  Sunrisers Hyderabad  Royal Challengers Bangalore
#
# ...

# %%
import numpy as np
import pandas as pd

batsman_name=pd.read_csv('deliveries.csv')
group=batsman_name.groupby('batsman')

group.get_group('A Ashish Reddy').shape
# Out:
# (196, 21)

# %% [markdown]
# # group=batsman_name.groupby('batsman')

# %%
import numpy as np
import pandas as pd

batsman_name=pd.read_csv('deliveries.csv')
group=batsman_name.groupby('batsman')

group.sum()
# Out:
#                 match_id  inning  \
# batsman
# A Ashish Reddy     90024     277
# A Chandila          2815       7
# A Chopra            7602      78
# A Choudhary          614      28
# A Flintoff          6908     100
# ...                  ...     ...
# YV Takawale        54862     305
# Yashpal Singh       9918     113
# Younis Khan          679      14
# Yuvraj Singh      634434    3064
# Z Khan             31770     226
#
#                                                      batting_team  \
# batsman
# A Ashish Reddy  Deccan ChargersDeccan ChargersDeccan ChargersD...
# A Chandila      Rajasthan RoyalsRajasthan RoyalsRajasthan Roya...
# A Chopra        Kolkata Knight RidersKolkata Knight RidersKolk...
# A Choudhary     Royal Challengers BangaloreRoyal Challengers B...
# A Flintoff      Chennai Super KingsChennai Super KingsChennai ...
# ...                                                           ...
# YV Takawale     Mumbai IndiansMumbai IndiansMumbai IndiansMumb...
# ...

# %% [markdown]
# # highest runs

# %%
import numpy as np
import pandas as pd

batsman_name=pd.read_csv('deliveries.csv')
group=batsman_name.groupby('batsman')

group['total_runs'].sum().sort_values(ascending=False).head()
# Out:
# batsman
# SK Raina     4745
# V Kohli      4588
# G Gambhir    4388
# RG Sharma    4334
# DA Warner    4213
# Name: total_runs, dtype: int64
